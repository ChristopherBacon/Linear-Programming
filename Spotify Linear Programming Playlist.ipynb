# %% [markdown]
# # Spotify Linear Programming Playlist

# %% [markdown]
# Let's use linear programming to solve an important business problem.. Making a banging 00's playlist using the Spotify API..

# %%
#import libraries
import spotipy
import pandas as pd
import pulp as pl
import re
from pulp import lpSum, LpStatus, LpStatusOptimal
from spotipy.oauth2 import SpotifyClientCredentials
import config

# %%
#register your project with Spotify to get these
cid = config.cid
secret = config.secret

# %%
#access the Spotify API
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
#spotify all out 00's Playlist
playlist = sp.user_playlist_tracks(playlist_id='37i9dQZF1DX4o1oenSJRJd')

# %%
all_out_00 = {'name':[], 'id':[]}

#get our playlist data
for x in range (1, 100):
    all_out_00['name'].append(playlist['items'][x]['track']['name'])
    all_out_00['id'].append(playlist['items'][x]['track']['id'])
    

all_out_00df = pd.DataFrame.from_dict(all_out_00)
#we have the playlist of tracks & IDs
all_out_00df
# Out:
#                                    name                      id
# 0                              Umbrella  49FYlytm3dAAraYgpoJZux
# 1                            Just Dance  5vQXxfGn1bjv5WESrYVVpw
# 2                   Party In The U.S.A.  3E7dfMvvCLUddWissuqMwr
# 3    Hips Don't Lie (feat. Wyclef Jean)  3ZFTkvIE7kyPt6Nu3PEa7V
# 4                                 Yeah!  2PkeVPcL32LA96cK5ySC3c
# ..                                  ...                     ...
# 94                             Rude Boy  60jzFy6Nn4M0iD1d94oteF
# 95                            Breakeven  4bCIt1XfHHGWo1UHKM11y9
# 96  One, Two Step (feat. Missy Elliott)  7uKcScNXuO3MWw6LowBjW1
# 97                      Let Me Love You  3ibKnFDaa3GhpPGlOUj7ff
# 98                       Lady Marmalade  2gocMpiwnMRLDejlcSJt7J
#
# [99 rows x 2 columns]

# %%
#get our artist refs
def get_artists(column_ref):
    artists = []
    for x in column_ref:
        artist = sp.search(x)['tracks']['items'][0]['artists'][0]['name']
        artists.append(artist)
    return artists

artists = get_artists(all_out_00df['name'])
all_out_00df['artist'] = artists

#get extra features from track id
danceability = []
energy = []
key = []
loudness = []
mode = []
speechiness = []
acousticness = []
instrumentalness = []
liveness = []
valence = []
tempo = []
duration_ms = []
time_signature = []

def audio_features(df):
    for x in df['id']:
        track = sp.audio_features(x)
        danceability.append(track[0]['danceability'])
        energy.append(track[0]['energy'])
        key.append(track[0]['key'])
        loudness.append(track[0]['loudness'])
        mode.append(track[0]['mode'])
        speechiness.append(track[0]['speechiness'])
        acousticness.append(track[0]['acousticness'])
        instrumentalness.append(track[0]['instrumentalness'])
        liveness.append(track[0]['liveness'])
        valence.append(track[0]['valence'])
        tempo.append(track[0]['tempo'])
        duration_ms.append(track[0]['duration_ms'])
        time_signature.append(track[0]['time_signature'])
    return 

#create our lists of features
audio_features(all_out_00df)


features = [danceability,energy,key,loudness,mode,
            speechiness,acousticness,instrumentalness,liveness,
            valence,tempo,duration_ms,time_signature]

columns = ['danceability','energy','key','loudness','mode',
            'speechiness','acousticness','instrumentalness','liveness',
            'valence','tempo','duration_ms','time_signature']


#create feature df
feat_dict = dict(zip(columns, features))
feat_df = pd.DataFrame.from_dict(feat_dict)

# %%
#join our frames
playlist_df = pd.concat([all_out_00df, feat_df], axis=1)

# %%
#we have our playlist
playlist_df
# Out:
#                                    name                      id  \
# 0                              Umbrella  49FYlytm3dAAraYgpoJZux
# 1                            Just Dance  5vQXxfGn1bjv5WESrYVVpw
# 2                   Party In The U.S.A.  3E7dfMvvCLUddWissuqMwr
# 3    Hips Don't Lie (feat. Wyclef Jean)  3ZFTkvIE7kyPt6Nu3PEa7V
# 4                                 Yeah!  2PkeVPcL32LA96cK5ySC3c
# ..                                  ...                     ...
# 94                             Rude Boy  60jzFy6Nn4M0iD1d94oteF
# 95                            Breakeven  4bCIt1XfHHGWo1UHKM11y9
# 96  One, Two Step (feat. Missy Elliott)  7uKcScNXuO3MWw6LowBjW1
# 97                      Let Me Love You  3ibKnFDaa3GhpPGlOUj7ff
# 98                       Lady Marmalade  2gocMpiwnMRLDejlcSJt7J
#
#                 artist  danceability  energy  key  loudness  mode  \
# 0              Rihanna         0.583   0.829    1    -4.603     1
# 1            Lady Gaga         0.821   0.741    1    -4.570     0
# 2          Miley Cyrus         0.652   0.698   10    -4.667     0
# 3              Shakira         0.778   0.824   10    -5.892     0
# 4                Usher         0.895   0.795    2    -4.693     1
# ..                 ...           ...     ...  ...       ...   ...
# 94             Rihanna         0.563   0.750   11    -4.496     1
# 95          The Script         0.630   0.698   10    -4.510     1
# 96               Ciara         0.944   0.511    5   -10.960     0
# 97               Mario         0.656   0.578    7    -8.970     0
# 98  Christina Aguilera         0.741   0.859    5    -2.223     1
#
#     speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0        0.1340       0.00864          0.000000    0.0426    0.575  174.028
# 1        0.0313       0.02780          0.000025    0.1900    0.741  118.984
# 2        0.0420       0.00112          0.000115    0.0886    0.470   96.021
# 3        0.0712       0.28400          0.000000    0.4050    0.756  100.024
# 4        0.0977       0.02190          0.000000    0.0403    0.574  105.004
# ..          ...           ...               ...       ...      ...      ...
# 94       0.1270       0.11300          0.000000    0.0788    0.812  173.906
# 95       0.0244       0.17300          0.000000    0.0789    0.529   94.023
# 96       0.1610       0.04200          0.001070    0.0379    0.842  113.046
# 97       0.0922       0.23500          0.000000    0.1180    0.556   94.514
# 98       0.0570       0.01480          0.000002    0.6640    0.611  109.905
#
#     duration_ms  time_signature
# 0        275987               4
# 1        244440               4
# 2        202067               4
# 3        218093               4
# 4        250067               4
# ..          ...             ...
# 94       222920               4
# 95       261427               4
# 96       203787               4
# 97       256733               4
# 98       265973               4
#
# [99 rows x 16 columns]

# %%
#clean up a little
playlist_df = playlist_df.drop_duplicates(subset=['name'])
playlist_df = playlist_df.reset_index()
playlist_df = playlist_df.drop(['index'], axis=1)

# %%
#we have our playlist df ready to work with
playlist_df
# Out:
#                                    name                      id  \
# 0                              Umbrella  49FYlytm3dAAraYgpoJZux
# 1                            Just Dance  5vQXxfGn1bjv5WESrYVVpw
# 2                   Party In The U.S.A.  3E7dfMvvCLUddWissuqMwr
# 3    Hips Don't Lie (feat. Wyclef Jean)  3ZFTkvIE7kyPt6Nu3PEa7V
# 4                                 Yeah!  2PkeVPcL32LA96cK5ySC3c
# ..                                  ...                     ...
# 94                             Rude Boy  60jzFy6Nn4M0iD1d94oteF
# 95                            Breakeven  4bCIt1XfHHGWo1UHKM11y9
# 96  One, Two Step (feat. Missy Elliott)  7uKcScNXuO3MWw6LowBjW1
# 97                      Let Me Love You  3ibKnFDaa3GhpPGlOUj7ff
# 98                       Lady Marmalade  2gocMpiwnMRLDejlcSJt7J
#
#                 artist  danceability  energy  key  loudness  mode  \
# 0              Rihanna         0.583   0.829    1    -4.603     1
# 1            Lady Gaga         0.821   0.741    1    -4.570     0
# 2          Miley Cyrus         0.652   0.698   10    -4.667     0
# 3              Shakira         0.778   0.824   10    -5.892     0
# 4                Usher         0.895   0.795    2    -4.693     1
# ..                 ...           ...     ...  ...       ...   ...
# 94             Rihanna         0.563   0.750   11    -4.496     1
# 95          The Script         0.630   0.698   10    -4.510     1
# 96               Ciara         0.944   0.511    5   -10.960     0
# 97               Mario         0.656   0.578    7    -8.970     0
# 98  Christina Aguilera         0.741   0.859    5    -2.223     1
#
#     speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0        0.1340       0.00864          0.000000    0.0426    0.575  174.028
# 1        0.0313       0.02780          0.000025    0.1900    0.741  118.984
# 2        0.0420       0.00112          0.000115    0.0886    0.470   96.021
# 3        0.0712       0.28400          0.000000    0.4050    0.756  100.024
# 4        0.0977       0.02190          0.000000    0.0403    0.574  105.004
# ..          ...           ...               ...       ...      ...      ...
# 94       0.1270       0.11300          0.000000    0.0788    0.812  173.906
# 95       0.0244       0.17300          0.000000    0.0789    0.529   94.023
# 96       0.1610       0.04200          0.001070    0.0379    0.842  113.046
# 97       0.0922       0.23500          0.000000    0.1180    0.556   94.514
# 98       0.0570       0.01480          0.000002    0.6640    0.611  109.905
#
#     duration_ms  time_signature
# 0        275987               4
# 1        244440               4
# 2        202067               4
# 3        218093               4
# 4        250067               4
# ..          ...             ...
# 94       222920               4
# 95       261427               4
# 96       203787               4
# 97       256733               4
# 98       265973               4
#
# [99 rows x 16 columns]

# %%
#Problem: Create a Noughties playlists most songs in 90 mins
prob = pl.LpProblem('NoughtiesPlaylist', pl.LpMaximize)

# %%
#create decision variables - 
decision_variables = []
for rownum, row in playlist_df.iterrows():
    variable = str('x' + str(rownum))
    variable = pl.LpVariable(str(variable), lowBound = 0, upBound = 1, cat= 'Integer') #make variables binary
    decision_variables.append(variable)

print ("Total number of decision_variables: " + str(len(decision_variables)))
print(decision_variables)
# Out:
# Total number of decision_variables: 99
# [x0, x1, x2, x3, x4, x5, x6, x7, x8, x9, x10, x11, x12, x13, x14, x15, x16, x17, x18, x19, x20, x21, x22, x23, x24, x25, x26, x27, x28, x29, x30, x31, x32, x33, x34, x35, x36, x37, x38, x39, x40, x41, x42, x43, x44, x45, x46, x47, x48, x49, x50, x51, x52, x53, x54, x55, x56, x57, x58, x59, x60, x61, x62, x63, x64, x65, x66, x67, x68, x69, x70, x71, x72, x73, x74, x75, x76, x77, x78, x79, x80, x81, x82, x83, x84, x85, x86, x87, x88, x89, x90, x91, x92, x93, x94, x95, x96, x97, x98]

# %%
#create optimization function
total_tracks = ""
for i, track in enumerate(decision_variables):
    total_tracks += track

prob += total_tracks
print ("Optimization function: " + str(total_tracks))
# Out:
# Optimization function: x0 + x1 + x10 + x11 + x12 + x13 + x14 + x15 + x16 + x17 + x18 + x19 + x2 + x20 + x21 + x22 + x23 + x24 + x25 + x26 + x27 + x28 + x29 + x3 + x30 + x31 + x32 + x33 + x34 + x35 + x36 + x37 + x38 + x39 + x4 + x40 + x41 + x42 + x43 + x44 + x45 + x46 + x47 + x48 + x49 + x5 + x50 + x51 + x52 + x53 + x54 + x55 + x56 + x57 + x58 + x59 + x6 + x60 + x61 + x62 + x63 + x64 + x65 + x66 + x67 + x68 + x69 + x7 + x70 + x71 + x72 + x73 + x74 + x75 + x76 + x77 + x78 + x79 + x8 + x80 + x81 + x82 + x83 + x84 + x85 + x86 + x87 + x88 + x89 + x9 + x90 + x91 + x92 + x93 + x94 + x95 + x96 + x97 + x98

# %%
#total duration of our playlist in milliseconds
playlist_df['duration_ms'].sum()
# Out:
# 22742571

# %%
#create lists for additional data to create constraints for our maximisation problem
tracks_duration = []
danceability = []
loudness =[]
mode = []
tempo = []

for i in range(0,99):
    track_total_dur = decision_variables[i]*playlist_df['duration_ms'][i]
    tracks_duration.append(track_total_dur)

for i in range(0,99):
    dability = decision_variables[i]*playlist_df['danceability'][i]
    danceability.append(dability)

for i in range(0,99):
    ldness = decision_variables[i]*playlist_df['loudness'][i]
    loudness.append(ldness)
    
for i in range(0,99):    
    mde = decision_variables[i]*playlist_df['mode'][i]
    mode.append(mde)
    
for i in range(0,99):    
    tpo = decision_variables[i]*playlist_df['tempo'][i]
    tempo.append(tpo)

# %%
#define our constraints
prob += lpSum(tracks_duration) <= 7200000, "PartyLengthMax"
prob += lpSum(tracks_duration) >= 5400000, "PartyLengthMin"
prob += lpSum(danceability) >= 15, "Danceability"
prob += lpSum(tempo) >= 900, "Tempo"

# %%
#our final problem with constraints
print(prob)
#write the problem to an LP file
prob.writeLP("SpotifyPlaylist.lp" )
# Out:
# NoughtiesPlaylist:
# MAXIMIZE
# 1*x0 + 1*x1 + 1*x10 + 1*x11 + 1*x12 + 1*x13 + 1*x14 + 1*x15 + 1*x16 + 1*x17 + 1*x18 + 1*x19 + 1*x2 + 1*x20 + 1*x21 + 1*x22 + 1*x23 + 1*x24 + 1*x25 + 1*x26 + 1*x27 + 1*x28 + 1*x29 + 1*x3 + 1*x30 + 1*x31 + 1*x32 + 1*x33 + 1*x34 + 1*x35 + 1*x36 + 1*x37 + 1*x38 + 1*x39 + 1*x4 + 1*x40 + 1*x41 + 1*x42 + 1*x43 + 1*x44 + 1*x45 + 1*x46 + 1*x47 + 1*x48 + 1*x49 + 1*x5 + 1*x50 + 1*x51 + 1*x52 + 1*x53 + 1*x54 + 1*x55 + 1*x56 + 1*x57 + 1*x58 + 1*x59 + 1*x6 + 1*x60 + 1*x61 + 1*x62 + 1*x63 + 1*x64 + 1*x65 + 1*x66 + 1*x67 + 1*x68 + 1*x69 + 1*x7 + 1*x70 + 1*x71 + 1*x72 + 1*x73 + 1*x74 + 1*x75 + 1*x76 + 1*x77 + 1*x78 + 1*x79 + 1*x8 + 1*x80 + 1*x81 + 1*x82 + 1*x83 + 1*x84 + 1*x85 + 1*x86 + 1*x87 + 1*x88 + 1*x89 + 1*x9 + 1*x90 + 1*x91 + 1*x92 + 1*x93 + 1*x94 + 1*x95 + 1*x96 + 1*x97 + 1*x98 + 0
# SUBJECT TO
# PartyLengthMax: 275987 x0 + 244440 x1 + 204587 x10 + 199640 x11 + 211160 x12
#  + 242293 x13 + 242373 x14 + 219720 x15 + 179640 x16 + 238627 x17 + 199693 x18
#  + 188960 x19 + 202067 x2 + 182307 x20 + 220227 x21 + 198800 x22 + 202613 x23
#  + 193147 x24 + 259333 x25 + 267080 x26 + 261640 x27 + 202850 x28 + 294640 x29
#  + 218093 x3 + 197124 x30 + 205360 x31 + 229413 x32 + 298853 x33 + 215160 x34
#  + 244507 x35 + 237200 x36 + 236133 x37 + 262693 x38 + 230120 x39 + 250067 x4
#  + 212400 x40 + 218333 x41 + 272533 x42 + 224400 x43 + 266840 x44 + 196160 x45
#  + 227853 x46 + 223253 x47 + 231400 x48 + 195853 x49 + 246960 x5 + 216667 x50
#  + 264373 x51 + 193213 x52 + 213293 x53 + 199027 x54 + 204000 x55 + 253813 x56
#  + 268120 x57 + 202653 x58 + 242733 x59 + 235267 x6 + 249867 x60 + 272080 x61
#  + 276920 x62 + 254027 x63 + 223520 x64 + 211413 x65 + 215480 x66 + 292373 x67
#  + 241667 x68 + 187840 x69 + 230747 x7 + 284733 x70 + 238920 x71 + 246467 x72
#  + 258827 x73 + 251240 x74 + 232693 x75 + 220627 x76 + 207187 x77 + 250373 x78
#  + 237920 x79 + 289133 x8 + 179120 x80 + 192360 x81 + 220373 x82 + 213520 x83
#  + 212280 x84 + 246573 x85 + 218093 x86 + 196227 x87 + 228347 x88 + 216480 x89
#  + 212107 x9 + 258893 x90 + 208067 x91 + 189693 x92 + 199853 x93 + 222920 x94
#  + 261427 x95 + 203787 x96 + 256733 x97 + 265973 x98 <= 7200000
#
# PartyLengthMin: 275987 x0 + 244440 x1 + 204587 x10 + 199640 x11 + 211160 x12
#  + 242293 x13 + 242373 x14 + 219720 x15 + 179640 x16 + 238627 x17 + 199693 x18
#  + 188960 x19 + 202067 x2 + 182307 x20 + 220227 x21 + 198800 x22 + 202613 x23
#  + 193147 x24 + 259333 x25 + 267080 x26 + 261640 x27 + 202850 x28 + 294640 x29
#  + 218093 x3 + 197124 x30 + 205360 x31 + 229413 x32 + 298853 x33 + 215160 x34
#  + 244507 x35 + 237200 x36 + 236133 x37 + 262693 x38 + 230120 x39 + 250067 x4
#  + 212400 x40 + 218333 x41 + 272533 x42 + 224400 x43 + 266840 x44 + 196160 x45
#  + 227853 x46 + 223253 x47 + 231400 x48 + 195853 x49 + 246960 x5 + 216667 x50
#  + 264373 x51 + 193213 x52 + 213293 x53 + 199027 x54 + 204000 x55 + 253813 x56
#  + 268120 x57 + 202653 x58 + 242733 x59 + 235267 x6 + 249867 x60 + 272080 x61
#  + 276920 x62 + 254027 x63 + 223520 x64 + 211413 x65 + 215480 x66 + 292373 x67
#  + 241667 x68 + 187840 x69 + 230747 x7 + 284733 x70 + 238920 x71 + 246467 x72
#  + 258827 x73 + 251240 x74 + 232693 x75 + 220627 x76 + 207187 x77 + 250373 x78
#  + 237920 x79 + 289133 x8 + 179120 x80 + 192360 x81 + 220373 x82 + 213520 x83
#  + 212280 x84 + 246573 x85 + 218093 x86 + 196227 x87 + 228347 x88 + 216480 x89
#  + 212107 x9 + 258893 x90 + 208067 x91 + 189693 x92 + 199853 x93 + 222920 x94
#  + 261427 x95 + 203787 x96 + 256733 x97 + 265973 x98 >= 5400000
#
# Danceability: 0.583 x0 + 0.821 x1 + 0.544 x10 + 0.571 x11 + 0.751 x12
#  + 0.808 x13 + 0.486 x14 + 0.499 x15 + 0.699 x16 + 0.707 x17 + 0.755 x18
#  + 0.664 x19 + 0.652 x2 + 0.706 x20 + 0.706 x21 + 0.774 x22 + 0.751 x23
#  + 0.624 x24 + 0.706 x25 + 0.835 x26 + 0.508 x27 + 0.7 x28 + 0.695 x29
#  + 0.778 x3 + 0.633 x30 + 0.776 x31 + 0.697 x32 + 0.64 x33 + 0.534 x34
#  + 0.582 x35 + 0.851 x36 + 0.646 x37 + 0.635 x38 + 0.62 x39 + 0.895 x4
#  + 0.584 x40 + 0.554 x41 + 0.835 x42 + 0.724 x43 + 0.81 x44 + 0.793 x45
#  + 0.447 x46 + 0.706 x47 + 0.918 x48 + 0.813 x49 + 0.779 x5 + 0.675 x50
#  + 0.466 x51 + 0.426 x52 + 0.768 x53 + 0.762 x54 + 0.487 x55 + 0.649 x56
#  + 0.708 x57 + 0.604 x58 + 0.967 x59 + 0.618 x6 + 0.63 x60 + 0.875 x61
#  + 0.491 x62 + 0.514 x63 + 0.873 x64 + 0.707 x65 + 0.801 x66 + 0.906 x67
#  + 0.543 x68 + 0.845 x69 + 0.649 x7 + 0.727 x70 + 0.677 x71 + 0.756 x72
#  + 0.583 x73 + 0.788 x74 + 0.632 x75 + 0.825 x76 + 0.452 x77 + 0.894 x78
#  + 0.566 x79 + 0.743 x8 + 0.731 x80 + 0.791 x81 + 0.583 x82 + 0.57 x83
#  + 0.735 x84 + 0.81 x85 + 0.962 x86 + 0.688 x87 + 0.512 x88 + 0.479 x89
#  + 0.657 x9 + 0.796 x90 + 0.694 x91 + 0.753 x92 + 0.926 x93 + 0.563 x94
#  + 0.63 x95 + 0.944 x96 + 0.656 x97 + 0.741 x98 >= 15
#
# Tempo: 174.028 x0 + 118.984 x1 + 153.629 x10 + 172.716 x11 + 95.053 x12
#  + 114.328 x13 + 138.015 x14 + 76.76 x15 + 129.996 x16 + 124.921 x17
#  + 120.028 x18 + 131.006 x19 + 96.021 x2 + 91.031 x20 + 132.032 x21
#  + 143.04 x22 + 119.975 x23 + 86.059 x24 + 100.011 x25 + 122.668 x26
#  + 79.983 x27 + 122.031 x28 + 119.002 x29 + 100.024 x3 + 142.027 x30
#  + 102.996 x31 + 82.082 x32 + 99.931 x33 + 126.019 x34 + 77.982 x35
#  + 118.999 x36 + 99.165 x37 + 104.054 x38 + 144.926 x39 + 105.004 x4
#  + 82.499 x40 + 157.995 x41 + 94.059 x42 + 139 x43 + 109.97 x44 + 107.661 x45
#  + 175.868 x46 + 110.443 x47 + 128.008 x48 + 130.011 x49 + 99.019 x5
#  + 97.03 x50 + 160.033 x51 + 193.437 x52 + 129.969 x53 + 110.009 x54
#  + 149.937 x55 + 89.969 x56 + 113.082 x57 + 122.018 x58 + 117 x59 + 118.984 x6
#  + 89.946 x60 + 120.002 x61 + 173.585 x62 + 161.109 x63 + 116.943 x64
#  + 97.003 x65 + 110.01 x66 + 129.055 x67 + 117.923 x68 + 100 x69 + 126.03 x7
#  + 117.932 x70 + 137.046 x71 + 119.961 x72 + 123.055 x73 + 113.324 x74
#  + 119.397 x75 + 122.021 x76 + 92.791 x77 + 105.018 x78 + 94.991 x79
#  + 127.96 x8 + 114.759 x80 + 114.98 x81 + 139.82 x82 + 162.084 x83
#  + 132.964 x84 + 130.99 x85 + 126.016 x86 + 127.866 x87 + 180.114 x88
#  + 92.959 x89 + 65.997 x9 + 132.722 x90 + 121.949 x91 + 113.029 x92
#  + 110.007 x93 + 173.906 x94 + 94.023 x95 + 113.046 x96 + 94.514 x97
#  + 109.905 x98 >= 900
#
# VARIABLES
# 0 <= x0 <= 1 Integer
# 0 <= x1 <= 1 Integer
# 0 <= x10 <= 1 Integer
# 0 <= x11 <= 1 Integer
# 0 <= x12 <= 1 Integer
# 0 <= x13 <= 1 Integer
# 0 <= x14 <= 1 Integer
# 0 <= x15 <= 1 Integer
# 0 <= x16 <= 1 Integer
# 0 <= x17 <= 1 Integer
# 0 <= x18 <= 1 Integer
# 0 <= x19 <= 1 Integer
# 0 <= x2 <= 1 Integer
# 0 <= x20 <= 1 Integer
# 0 <= x21 <= 1 Integer
# 0 <= x22 <= 1 Integer
# 0 <= x23 <= 1 Integer
# 0 <= x24 <= 1 Integer
# 0 <= x25 <= 1 Integer
# 0 <= x26 <= 1 Integer
# 0 <= x27 <= 1 Integer
# 0 <= x28 <= 1 Integer
# 0 <= x29 <= 1 Integer
# 0 <= x3 <= 1 Integer
# 0 <= x30 <= 1 Integer
# 0 <= x31 <= 1 Integer
# 0 <= x32 <= 1 Integer
# 0 <= x33 <= 1 Integer
# 0 <= x34 <= 1 Integer
# 0 <= x35 <= 1 Integer
# 0 <= x36 <= 1 Integer
# 0 <= x37 <= 1 Integer
# 0 <= x38 <= 1 Integer
# 0 <= x39 <= 1 Integer
# 0 <= x4 <= 1 Integer
# 0 <= x40 <= 1 Integer
# 0 <= x41 <= 1 Integer
# 0 <= x42 <= 1 Integer
# 0 <= x43 <= 1 Integer
# 0 <= x44 <= 1 Integer
# 0 <= x45 <= 1 Integer
# 0 <= x46 <= 1 Integer
# 0 <= x47 <= 1 Integer
# 0 <= x48 <= 1 Integer
# 0 <= x49 <= 1 Integer
# 0 <= x5 <= 1 Integer
# 0 <= x50 <= 1 Integer
# 0 <= x51 <= 1 Integer
# 0 <= x52 <= 1 Integer
# 0 <= x53 <= 1 Integer
# 0 <= x54 <= 1 Integer
# 0 <= x55 <= 1 Integer
# 0 <= x56 <= 1 Integer
# 0 <= x57 <= 1 Integer
# 0 <= x58 <= 1 Integer
# 0 <= x59 <= 1 Integer
# 0 <= x6 <= 1 Integer
# 0 <= x60 <= 1 Integer
# 0 <= x61 <= 1 Integer
# 0 <= x62 <= 1 Integer
# 0 <= x63 <= 1 Integer
# 0 <= x64 <= 1 Integer
# 0 <= x65 <= 1 Integer
# 0 <= x66 <= 1 Integer
# 0 <= x67 <= 1 Integer
# 0 <= x68 <= 1 Integer
# 0 <= x69 <= 1 Integer
# 0 <= x7 <= 1 Integer
# 0 <= x70 <= 1 Integer
# 0 <= x71 <= 1 Integer
# 0 <= x72 <= 1 Integer
# 0 <= x73 <= 1 Integer
# 0 <= x74 <= 1 Integer
# 0 <= x75 <= 1 Integer
# 0 <= x76 <= 1 Integer
# 0 <= x77 <= 1 Integer
# 0 <= x78 <= 1 Integer
# 0 <= x79 <= 1 Integer
# 0 <= x8 <= 1 Integer
# 0 <= x80 <= 1 Integer
# 0 <= x81 <= 1 Integer
# 0 <= x82 <= 1 Integer
# 0 <= x83 <= 1 Integer
# 0 <= x84 <= 1 Integer
# 0 <= x85 <= 1 Integer
# 0 <= x86 <= 1 Integer
# 0 <= x87 <= 1 Integer
# 0 <= x88 <= 1 Integer
# 0 <= x89 <= 1 Integer
# 0 <= x9 <= 1 Integer
# 0 <= x90 <= 1 Integer
# 0 <= x91 <= 1 Integer
# 0 <= x92 <= 1 Integer
# 0 <= x93 <= 1 Integer
# 0 <= x94 <= 1 Integer
# 0 <= x95 <= 1 Integer
# 0 <= x96 <= 1 Integer
# 0 <= x97 <= 1 Integer
# 0 <= x98 <= 1 Integer
# [x0,
#  x1,
#  x10,
#  x11,
#  x12,
#  x13,
#  x14,
#  x15,
#  x16,
#  x17,
#  x18,
#  x19,
#  x2,
#  x20,
#  x21,
#  x22,
#  x23,
#  x24,
#  x25,
#  x26,
#  x27,
#  x28,
#  x29,
#  x3,
#  x30,
#  x31,
#  x32,
#  x33,
#  x34,
#  x35,
#  x36,
#  x37,
#  x38,
#  x39,
#  x4,
#  x40,
#  x41,
#  x42,
#  x43,
#  x44,
#  x45,
#  x46,
#  x47,
#  x48,
#  x49,
#  x5,
#  x50,
#  x51,
#  x52,
#  x53,
#  x54,
#  x55,
#  x56,
#  x57,
#  x58,
#  x59,
#  x6,
#  x60,
#  x61,
#  x62,
#  x63,
#  x64,
#  x65,
#  x66,
#  x67,
#  x68,
#  x69,
#  x7,
#  x70,
#  x71,
#  x72,
#  x73,
#  x74,
#  x75,
#  x76,
#  x77,
#  x78,
#  x79,
#  x8,
#  x80,
#  x81,
#  x82,
#  x83,
#  x84,
#  x85,
#  x86,
#  x87,
#  x88,
#  x89,
#  x9,
#  x90,
#  x91,
#  x92,
#  x93,
#  x94,
#  x95,
#  x96,
#  x97,
#  x98]

# %%
#the problem is solved using PuLP's choice of Solver
prob.solve()

#the status of the solution is printed to the screen
print("status:", LpStatus[prob.status])

#each of the variables is printed with it's resolved optimum value
print ("decision_variables: ")
for v in prob.variables():
    print(v.name, "=", v.varValue)
# Out:
# status: Optimal
# decision_variables:
# x0 = 0.0
# x1 = 0.0
# x10 = 1.0
# x11 = 1.0
# x12 = 1.0
# x13 = 0.0
# x14 = 0.0
# x15 = 0.0
# x16 = 1.0
# x17 = 0.0
# x18 = 1.0
# x19 = 1.0
# x2 = 1.0
# x20 = 1.0
# x21 = 0.0
# x22 = 1.0
# x23 = 1.0
# x24 = 1.0
# x25 = 0.0
# x26 = 0.0
# x27 = 0.0
# x28 = 1.0
# x29 = 0.0
# x3 = 0.0
# x30 = 1.0
# x31 = 1.0
# x32 = 0.0
# x33 = 0.0
# x34 = 0.0
# x35 = 0.0
# x36 = 0.0
# x37 = 0.0
# x38 = 0.0
# x39 = 0.0
# x4 = 0.0
# x40 = 1.0
# x41 = 0.0
# x42 = 0.0
# x43 = 0.0
# x44 = 0.0
# x45 = 1.0
# x46 = 0.0
# x47 = 0.0
# x48 = 0.0
# x49 = 1.0
# x5 = 0.0
# x50 = 0.0
# x51 = 0.0
# x52 = 1.0
# x53 = 1.0
# x54 = 1.0
# x55 = 1.0
# x56 = 0.0
# x57 = 0.0
# x58 = 1.0
# x59 = 0.0
# x6 = 0.0
# x60 = 0.0
# x61 = 0.0
# x62 = 0.0
# x63 = 0.0
# x64 = 0.0
# x65 = 1.0
# x66 = 0.0
# x67 = 0.0
# x68 = 0.0
# x69 = 1.0
# x7 = 0.0
# x70 = 0.0
# x71 = 0.0
# x72 = 0.0
# x73 = 0.0
# x74 = 0.0
# x75 = 0.0
# x76 = 0.0
# x77 = 1.0
# x78 = 0.0
# x79 = 0.0
# x8 = 0.0
# x80 = 1.0
# x81 = 1.0
# x82 = 0.0
# x83 = 1.0
# x84 = 1.0
# x85 = 0.0
# x86 = 0.0
# x87 = 1.0
# x88 = 0.0
# x89 = 0.0
# x9 = 1.0
# x90 = 0.0
# x91 = 1.0
# x92 = 1.0
# x93 = 1.0
# x94 = 0.0
# x95 = 0.0
# x96 = 1.0
# x97 = 0.0
# x98 = 0.0

# %%
#reorder results
variable_name = []
variable_value = []

for v in prob.variables():
    variable_name.append(v.name)
    variable_value.append(v.varValue)

df = pd.DataFrame({'variable': variable_name, 'value': variable_value})
for rownum, row in df.iterrows():
    value = re.findall(r'(\d+)', row['variable'])
    df.loc[rownum, 'variable'] = int(value[0])

df = df.sort_index()


#append results
for rownum, row in playlist_df.iterrows():
     for results_rownum, results_row in df.iterrows():
        if rownum == results_row['variable']:
            playlist_df.loc[rownum, 'decision'] = results_row['value']

# %%
#function to convert milliseconds to mins:secs per standard song duration formats
def song_duration(millis):
    seconds=(millis/1000)%60
    minutes=(millis/(1000*60))%60
    return "%d:%d" % (minutes, seconds)

# %%
#Apply time conversion to the dataframe
playlist_df['duration'] = playlist_df['duration_ms'].apply(song_duration)
playlist_df
# Out:
#                                    name                      id  \
# 0                              Umbrella  49FYlytm3dAAraYgpoJZux
# 1                            Just Dance  5vQXxfGn1bjv5WESrYVVpw
# 2                   Party In The U.S.A.  3E7dfMvvCLUddWissuqMwr
# 3    Hips Don't Lie (feat. Wyclef Jean)  3ZFTkvIE7kyPt6Nu3PEa7V
# 4                                 Yeah!  2PkeVPcL32LA96cK5ySC3c
# ..                                  ...                     ...
# 94                             Rude Boy  60jzFy6Nn4M0iD1d94oteF
# 95                            Breakeven  4bCIt1XfHHGWo1UHKM11y9
# 96  One, Two Step (feat. Missy Elliott)  7uKcScNXuO3MWw6LowBjW1
# 97                      Let Me Love You  3ibKnFDaa3GhpPGlOUj7ff
# 98                       Lady Marmalade  2gocMpiwnMRLDejlcSJt7J
#
#                 artist  danceability  energy  key  loudness  mode  \
# 0              Rihanna         0.583   0.829    1    -4.603     1
# 1            Lady Gaga         0.821   0.741    1    -4.570     0
# 2          Miley Cyrus         0.652   0.698   10    -4.667     0
# 3              Shakira         0.778   0.824   10    -5.892     0
# 4                Usher         0.895   0.795    2    -4.693     1
# ..                 ...           ...     ...  ...       ...   ...
# 94             Rihanna         0.563   0.750   11    -4.496     1
# 95          The Script         0.630   0.698   10    -4.510     1
# 96               Ciara         0.944   0.511    5   -10.960     0
# 97               Mario         0.656   0.578    7    -8.970     0
# 98  Christina Aguilera         0.741   0.859    5    -2.223     1
#
#     speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0        0.1340       0.00864          0.000000    0.0426    0.575  174.028
# 1        0.0313       0.02780          0.000025    0.1900    0.741  118.984
# 2        0.0420       0.00112          0.000115    0.0886    0.470   96.021
# 3        0.0712       0.28400          0.000000    0.4050    0.756  100.024
# 4        0.0977       0.02190          0.000000    0.0403    0.574  105.004
# ..          ...           ...               ...       ...      ...      ...
# 94       0.1270       0.11300          0.000000    0.0788    0.812  173.906
# 95       0.0244       0.17300          0.000000    0.0789    0.529   94.023
# 96       0.1610       0.04200          0.001070    0.0379    0.842  113.046
# 97       0.0922       0.23500          0.000000    0.1180    0.556   94.514
# 98       0.0570       0.01480          0.000002    0.6640    0.611  109.905
#
#     duration_ms  time_signature  decision duration
# 0        275987               4       0.0     4:35
# 1        244440               4       0.0      4:4
# 2        202067               4       1.0     3:22
# 3        218093               4       0.0     3:38
# 4        250067               4       0.0     4:10
# ..          ...             ...       ...      ...
# 94       222920               4       0.0     3:42
# 95       261427               4       0.0     4:21
# 96       203787               4       1.0     3:23
# 97       256733               4       0.0     4:16
# 98       265973               4       0.0     4:25
#
# [99 rows x 18 columns]

# %%
#selecting only tracks that made the final playlist
playlist_df[playlist_df['decision'] == 1]
# Out:
#                                                  name                      id  \
# 2                                 Party In The U.S.A.  3E7dfMvvCLUddWissuqMwr
# 9                                                Down  7LP4Es66zdY7CyjepqmvAg
# 10                                        Sex on Fire  395C2pn0PdOYPzM4B1jLoO
# 11                                        Bye Bye Bye  2yiZyjMEByt9sJBZWnWaDR
# 12                             Oops!...I Did It Again  6naxalmIoLFWR0siv8dnQQ
# 16                                    I Kissed A Girl  14iN3o8ptQ8cFVZTEmyQRV
# 18                                            TiK ToK  0HPD5WQqrq7wPWR7P7Dw1i
# 19                                  Since U Been Gone  3iJTbZDSnZ676y5qObWDm0
# 20                                             Replay  4E5P1XyAFtrjpiIxkydly4
# 22                                              Toxic  4fbaKWFRghusXd4bSBvvfN
# 23                                           Dynamite  2CEgGE6aESpnmtfiZwYlbV
# 24            We Are Never Ever Getting Back Together  1F6oGPF75u9RuHH4BGx9Bf
# 28                                   Raise Your Glass  05qq6mwIbG1ZsQhlMKyDwN
# 30                                Every time we touch  2gOlrge3YTmYPwsCGgU62K
# 31                       The Tide Is High - Radio Mix  5WuVWOngcRkMOx9RRLCvui
# 40                                      About You Now  1ctdfJSzp6qF2iDAVdDrfl
# 45                                 Whenever, Wherever  2lnzGkdtDj5mtlcOW2yRtG
# 49                            Sexy Bitch (feat. Akon)  127uq83uGFapbddqiMUKky
# 52                   Single Ladies (Put a Ring on It)  5R9a4t5t5O0IsznsrKPVro
# 53                        Cooler Than Me - Single Mix  2V4bv1fNWfTcyRJKmej6Sj
# 54                                         In My Head  6St9lR6dhV2tpCNVz7qfrS
# 55                                          Sk8er Boi  4omisSlTk6Dsq2iQD7MA07
# 58                                   Break Your Heart  3oN2Kq1h07LSSBSLYQp0Ns
# 65                                   World of Our Own  4SAHTVRe6EBhgAOWl49yPf
# 69  Jenny from the Block (feat. Jadakiss & Styles ...  7LqjznQwfrax7MjQXmxqdQ
# 77                                            So Sick  4SRqDmPxYX0pUb5B5ut2Ri
# 80                                      The Way I Are  2bLqfJjuC5syrsgDsZfGmn
# 81                                             Circus  7jk7gqyEonmVVYahZN5zhW
# 83                                              Crush  4wCD0qOFNRu1Q6O3N6ycm4
# 84                                  Shut Up And Drive  4Tn2llBm1g0UlWctmgPL8Z
# 87                                             Bubbly  1lkvpmrCaXK8QtliFDcHBO
# 91                                       Sweet Dreams  2wLMMcXV6sRtLijfLZP9oR
# 92    4 Minutes (feat. Justin Timberlake & Timbaland)  1oHClQEgDmmbcEx12Kc5nZ
# 93                                     Hollaback Girl  0eqH0ALoDQevq59YcQ53KE
# 96                One, Two Step (feat. Missy Elliott)  7uKcScNXuO3MWw6LowBjW1
#
#               artist  danceability  energy  key  loudness  mode  speechiness  \
# 2        Miley Cyrus         0.652   0.698   10    -4.667     0       0.0420
# 9           Jay Sean         0.657   0.695    2    -4.493     1       0.0321
# 10     Kings of Leon         0.544   0.903    9    -5.651     1       0.0545
# 11            *NSYNC         0.571   0.870    8    -3.877     0       0.0641
# 12    Britney Spears         0.751   0.834    1    -5.444     0       0.0437
# 16        Katy Perry         0.699   0.760    5    -3.173     1       0.0677
# 18             Kesha         0.755   0.837    2    -2.718     0       0.1420
# 19    Kelly Clarkson         0.664   0.741    0    -5.391     1       0.0343
# 20              Iyaz         0.706   0.751    9    -6.323     1       0.0708
# 22    Britney Spears         0.774   0.838    5    -3.914     0       0.1140
# 23               BTS         0.751   0.783    4    -3.724     1       0.0859
# 24      Taylor Swift         0.624   0.685    7    -5.902     1       0.1200
# 28              P!nk         0.700   0.708    7    -4.952     1       0.0870
# 30    Jonathan Young         0.633   0.976    8    -5.362     1       0.0519
# 31     Atomic Kitten         0.776   0.693    7    -2.528     1       0.0314
# 40  Miranda Cosgrove         0.584   0.699    1    -6.065     0       0.0378
# 45           Shakira         0.793   0.832    1    -4.862     0       0.0406
# 49      David Guetta         0.813   0.627   11    -5.018     0       0.0486
# 52           Beyoncé         0.426   0.584    1    -5.293     1       0.2960
# 53       Mike Posner         0.768   0.820    7    -4.630     0       0.0475
# 54     Ariana Grande         0.762   0.748    0    -4.150     0       0.0330
# 55     Avril Lavigne         0.487   0.900    0    -4.417     1       0.0482
# 58         Taio Cruz         0.604   0.918    3    -5.284     1       0.0312
# 65          Westlife         0.707   0.761    1    -4.635     1       0.0341
# 69    Jennifer Lopez         0.845   0.768    6    -5.448     1       0.1880
# 77             Ne-Yo         0.452   0.574    6    -8.336     1       0.3100
# 80         Timbaland         0.731   0.807    3    -6.492     0       0.1000
# 81    Britney Spears         0.791   0.733    6    -5.215     0       0.0520
# 83      Tessa Violet         0.570   0.664    0    -4.718     0       0.0322
# 84           Rihanna         0.735   0.826    1    -4.902     1       0.0349
# 87    Colbie Caillat         0.688   0.477    9    -6.684     1       0.0360
# 91        Eurythmics         0.694   0.825    1    -5.986     1       0.1110
# 92           Madonna         0.753   0.931    2    -4.922     1       0.0652
# 93      Gwen Stefani         0.926   0.916   10    -2.221     0       0.0929
# 96             Ciara         0.944   0.511    5   -10.960     0       0.1610
#
#     acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 2       0.001120          0.000115    0.0886    0.470   96.021       202067
# 9       0.010800          0.000000    0.0822    0.683   65.997       212107
# 10      0.001660          0.006320    0.1000    0.432  153.629       204587
# 11      0.019800          0.000007    0.0564    0.813  172.716       199640
# 12      0.300000          0.000018    0.3550    0.894   95.053       211160
# 16      0.002230          0.000000    0.1320    0.696  129.996       179640
# 18      0.099100          0.000000    0.2890    0.714  120.028       199693
# 19      0.001690          0.050200    0.1130    0.409  131.006       188960
# 20      0.173000          0.000000    0.1680    0.195   91.031       182307
# 22      0.024900          0.025000    0.2420    0.924  143.040       198800
# 23      0.003790          0.000000    0.0360    0.816  119.975       202613
# 24      0.010500          0.000022    0.1260    0.781   86.059       193147
# 28      0.006240          0.000000    0.0345    0.619  122.031       202850
# 30      0.002810          0.000013    0.3820    0.493  142.027       197124
# 31      0.023400          0.001770    0.0322    0.635  102.996       205360
# 40      0.000065          0.000061    0.4860    0.585   82.499       212400
# 45      0.236000          0.000011    0.2020    0.872  107.661       196160
# 49      0.077100          0.000616    0.1310    0.801  130.011       195853
# 52      0.038300          0.000000    0.1880    0.272  193.437       193213
# 53      0.179000          0.000000    0.7040    0.625  129.969       213293
# 54      0.026600          0.000000    0.3480    0.851  110.009       199027
# 55      0.000068          0.000000    0.3580    0.484  149.937       204000
# 58      0.031900          0.000000    0.0592    0.609  122.018       202653
# 65      0.016300          0.000000    0.0627    0.923   97.003       211413
# 69      0.007330          0.000005    0.0575    0.960  100.000       187840
# 77      0.246000          0.000000    0.1890    0.580   92.791       207187
# 80      0.181000          0.751000    0.3190    0.765  114.759       179120
# 81      0.147000          0.000381    0.0713    0.761  114.980       192360
# 83      0.008360          0.000012    0.0719    0.487  162.084       213520
# 84      0.001010          0.129000    0.1970    0.740  132.964       212280
# 87      0.594000          0.000000    0.1150    0.257  127.866       196227
# 91      0.089500          0.000019    0.0618    0.788  121.949       208067
# 92      0.009940          0.006960    0.2340    0.767  113.029       189693
# 93      0.350000          0.000006    0.0234    0.904  110.007       199853
# 96      0.042000          0.001070    0.0379    0.842  113.046       203787
#
#     time_signature  decision duration
# 2                4       1.0     3:22
# 9                4       1.0     3:32
# 10               4       1.0     3:24
# 11               4       1.0     3:19
# 12               4       1.0     3:31
# 16               4       1.0     2:59
# 18               4       1.0     3:19
# 19               4       1.0      3:8
# 20               4       1.0      3:2
# 22               4       1.0     3:18
# 23               4       1.0     3:22
# 24               4       1.0     3:13
# 28               4       1.0     3:22
# 30               4       1.0     3:17
# 31               4       1.0     3:25
# 40               4       1.0     3:32
# 45               4       1.0     3:16
# 49               4       1.0     3:15
# 52               4       1.0     3:13
# 53               4       1.0     3:33
# 54               4       1.0     3:19
# 55               4       1.0     3:24
# 58               4       1.0     3:22
# 65               4       1.0     3:31
# 69               4       1.0      3:7
# 77               4       1.0     3:27
# 80               4       1.0     2:59
# 81               4       1.0     3:12
# 83               4       1.0     3:33
# 84               4       1.0     3:32
# 87               4       1.0     3:16
# 91               4       1.0     3:28
# 92               4       1.0      3:9
# 93               4       1.0     3:19
# 96               4       1.0     3:23

# %% [markdown]
# Acknowledgements:
# Anna Nicanorova: Optimizing Life Everyday Problems Solved with Linear Programing in Python
# https://www.youtube.com/watch?v=7yZ5xxdkTb8
# https://github.com/AnnaNican
#
# PULP Doc:
# https://coin-or.github.io/pulp/
# Some great starter examples in this lot
#
# M373 Optimization:
# http://www.open.ac.uk/courses/modules/m373
# Great course from the OU that I undertook in my 3rd year degree, goes through many applications of linear/integer programming.
